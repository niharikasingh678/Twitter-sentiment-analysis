# %% [markdown]
# <a href="https://colab.research.google.com/github/niharikasingh678/Twitter-sentiment-analysis/blob/main/SAMiniproject_(1).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import re
import string
import numpy as np
import random
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
from plotly import graph_objs as go
import plotly.express as px
import plotly.figure_factory as ff
from collections import Counter

from PIL import Image
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator


import nltk
from nltk.corpus import stopwords

from tqdm import tqdm
import os
import nltk
import spacy
import random
from spacy.util import compounding
from spacy.util import minibatch

import warnings
warnings.filterwarnings("ignore")

import os

# %%
def random_colours(number_of_colors):
    '''
    Simple function for random colours generation.
    Input:
        number_of_colors - integer value indicating the number of colours which are going to be generated.
    Output:
        Color in the following format: ['#E86DA4'] .
    '''
    colors = []
    for i in range(number_of_colors):
        colors.append("#"+''.join([random.choice('0123456789ABCDEF') for j in range(6)]))
    return colors

# %%
train = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Tweets.csv')

# %%
print(train.shape)
# Out:
# (27481, 4)

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27481 entries, 0 to 27480
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   textID         27481 non-null  object
#  1   text           27480 non-null  object
#  2   selected_text  27480 non-null  object
#  3   sentiment      27481 non-null  object
# dtypes: object(4)
# memory usage: 858.9+ KB

# %%
train.dropna(inplace=True)

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 27480 entries, 0 to 27480
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   textID         27480 non-null  object
#  1   text           27480 non-null  object
#  2   selected_text  27480 non-null  object
#  3   sentiment      27480 non-null  object
# dtypes: object(4)
# memory usage: 1.0+ MB

# %%
train.head()
# Out:
#        textID                                               text  \
# 0  cb774db0d1                I`d have responded, if I were going
# 1  549e992a42      Sooo SAD I will miss you here in San Diego!!!
# 2  088c60f138                          my boss is bullying me...
# 3  9642c003ef                     what interview! leave me alone
# 4  358bd9e861   Sons of ****, why couldn`t they put them on t...
#
#                          selected_text sentiment
# 0  I`d have responded, if I were going   neutral
# 1                             Sooo SAD  negative
# 2                          bullying me  negative
# 3                       leave me alone  negative
# 4                        Sons of ****,  negative

# %%
train.describe()
# Out:
#             textID                                  text selected_text  \
# count        27480                                 27480         27480
# unique       27480                                 27480         22463
# top     cb774db0d1   I`d have responded, if I were going          good
# freq             1                                     1           199
#
#        sentiment
# count      27480
# unique         3
# top      neutral
# freq       11117

# %%
# function
def demoji(text):

    # frequent emojis whhich will be kept
    pattern = '😤|😡|😠|😑|🙄|🤨|😶|😱|🙀|😲|😓|😰|😢|😥|😭|😪|🤕|😔|😣|🙁|😒|😖|😕|🥴|🤒|☹️|😞|😷|🤧|😧|😨|😩|🥺|😦|😆|😀|🤭|🤩|😌|🥰|😁|😘|😂|😅|😊|😝|😙|😇'
    for word in text:
        if re.match(pattern, word):
            continue

        # remove all other non ascii characters
        text=text.replace(word, re.sub('[^\x00-\x7f]','', word)).strip()

    return text

# apply function
train['text']= train['text'].apply(demoji)

# %%
# funtion
def convert(text):

    # dictionary of emoji with their meaning
    d = {'😤':'frustrated','😡':'angry','😠':'angry','😱':'horrified','🙀':'shock','😲':'shock','🙄':'disapproval',
         '🤨':'suspicion','😶':'disappointment','😓':'sad','😰':'sad','😢':'sad','😥':'sad','😭':'sad','😪':'sad',
         '🤕':'sad','😔':'sad','😣':'sad','🙁':'sad','😒':'sad','😖':'sad','😕':'sad','🥴':'sad','🤒':'sad','☹️':'sad',
         '😞':'sad','😷':'sick','🤧':'sick','😧':'sad','😨':'sad','😩':'sad','🥺':'sad','😦':'sad','😫':'sad',
         '😆':'happy','😀':'smile','🤭':'embarrassment','🤩':'exciting','🥰':'affection','😁':'smile','😂':'laugh',
         '😅':'nervousness','😊':'smile','😝':'fun','😙':'affection','😇':'blessed'}

    for emoji, sentiment in d.items():
        text=text.replace(emoji, sentiment)
    return text

# apply function
train['senti_text']= train['text'].apply(convert)

# %%
temp = train.groupby('sentiment').count()['text'].reset_index().sort_values(by='text',ascending=False)
temp.style.background_gradient(cmap='Purples')
# Out:
# <style type="text/css">
# #T_b5056_row0_col1 {
#   background-color: #3f007d;
#   color: #f1f1f1;
# }
# #T_b5056_row1_col1 {
#   background-color: #dcdcec;
#   color: #000000;
# }
# #T_b5056_row2_col1 {
#   background-color: #fcfbfd;
#   color: #000000;
# }
# </style>
# <table id="T_b5056" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b5056_level0_col0" class="col_heading level0 col0" >sentiment</th>
#       <th id="T_b5056_level0_col1" class="col_heading level0 col1" >text</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b5056_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_b5056_row0_col0" class="data row0 col0" >neutral</td>
#       <td id="T_b5056_row0_col1" class="data row0 col1" >11117</td>
#     </tr>
#     <tr>
#       <th id="T_b5056_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_b5056_row1_col0" class="data row1 col0" >positive</td>
#       <td id="T_b5056_row1_col1" class="data row1 col1" >8582</td>
#     </tr>
#     <tr>
#       <th id="T_b5056_level0_row2" class="row_heading level0 row2" >0</th>
#       <td id="T_b5056_row2_col0" class="data row2 col0" >negative</td>
#       <td id="T_b5056_row2_col1" class="data row2 col1" >7781</td>
#     </tr>
#   </tbody>
# </table>

# %%
plt.figure(figsize=(12,6))
sns.countplot(x='sentiment',data=train)
# Out:
# <Axes: xlabel='sentiment', ylabel='count'>

# %%
fig = go.Figure(go.Funnelarea(
    text =temp.sentiment,
    values = temp.text,
    title = {"position": "top center", "text": "Funnel-Chart of Sentiment Distribution"}
    ))
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="0b36b879-e081-4ed5-8d2f-9a4677475c1e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0b36b879-e081-4ed5-8d2f-9a4677475c1e")) {                    Plotly.newPlot(                        "0b36b879-e081-4ed5-8d2f-9a4677475c1e",                        [{"text":["neutral","positive","negative"],"title":{"position":"top center","text":"Funnel-Chart of Sentiment Distribution"},"values":[11117,8582,7781],"type":"funnelarea"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"} ...

# %%
def jaccard(str1, str2):
    a = set(str1.lower().split())
    b = set(str2.lower().split())
    c = a.intersection(b)
    return float(len(c)) / (len(a) + len(b) - len(c))

# %%
results_jaccard=[]

for ind,row in train.iterrows():
    sentence1 = row.text
    sentence2 = row.selected_text

    jaccard_score = jaccard(sentence1,sentence2)
    results_jaccard.append([sentence1,sentence2,jaccard_score])

# %%
jaccard = pd.DataFrame(results_jaccard,columns=["text","selected_text","jaccard_score"])
train = train.merge(jaccard,how='outer')

# %%
train.head()
# Out:
#        textID                                               text  \
# 0  cb774db0d1                I`d have responded, if I were going
# 1  549e992a42      Sooo SAD I will miss you here in San Diego!!!
# 2  088c60f138                          my boss is bullying me...
# 3  9642c003ef                     what interview! leave me alone
# 4  358bd9e861   Sons of ****, why couldn`t they put them on t...
#
#                          selected_text sentiment  jaccard_score
# 0  I`d have responded, if I were going   neutral       1.000000
# 1                             Sooo SAD  negative       0.200000
# 2                          bullying me  negative       0.166667
# 3                       leave me alone  negative       0.600000
# 4                        Sons of ****,  negative       0.214286

# %%
train['Num_words_ST'] = train['selected_text'].apply(lambda x:len(str(x).split())) #Number Of words in Selected Text
train['Num_word_text'] = train['text'].apply(lambda x:len(str(x).split())) #Number Of words in main text
train['difference_in_words'] = train['Num_word_text'] - train['Num_words_ST'] #Difference in Number of words text and Selected Text

# %%
hist_data = [train['Num_words_ST'],train['Num_word_text']]

group_labels = ['Selected_Text', 'Text']

# Create distplot with custom bin_size
fig = ff.create_distplot(hist_data, group_labels,show_curve=False)
fig.update_layout(title_text='Distribution of Number Of words')
fig.update_layout(
    autosize=False,
    width=900,
    height=700,
    paper_bgcolor="LightSteelBlue",
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="9da08bf1-0691-4fea-9afa-2defb269eee7" class="plotly-graph-div" style="height:700px; width:900px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9da08bf1-0691-4fea-9afa-2defb269eee7")) {                    Plotly.newPlot(                        "9da08bf1-0691-4fea-9afa-2defb269eee7",                        [{"autobinx":false,"histnorm":"probability density","legendgroup":"Selected_Text","marker":{"color":"rgb(31, 119, 180)"},"name":"Selected_Text","opacity":0.7,"x":[7,2,2,3,3,12,1,2,3,5,23,1,1,1,6,5,1,1,1,6,13,1,12,18,13,11,2,2,1,6,1,1,10,1,20,8,1,24,2,4,20,3,1,25,3,18,1,5,3,8,14,10,6,10,4,11,1,4,4,6,9,2,5,1,1,4,2,16,1,9,6,1,25,18,27,27,1,4,4,12,2,1,6,1,3,10,27,28,4,1,3,9,9,1,9,9,1,1,12,1,1,5,1,1,1,11,12,1,1,7,15,2,2,25,3,4,1,4,1,24,13,25,3,2,2,3,13,1,4,2,1,4,1,1,2,2,20,21,5,5,31,1,1,3,2,17,6,9,1,1,22,3,1,1,6,6,2,22,9,11,2,6,7,1,5,1,4,16,1,1,2,5,1,23,12,5,1,7,1,20,9,4,13,1,10,2,2,1,18,1,4,2,14,11,5,4,1,2,19,15,3,1,7,3,21,1,1,7,4,5,3,7,1,1,13,4,18,2,2,20,6,3,22,6,1,5,10,1,6,2,10,5,1,6,19,11,1,7,1,1,7,27,14,7,13,1,21,6,1,7,8,14,1,23,4,12,5,1,14,15,2,4,11,21,23,3,1,4,24,2,16,2,10,1,2,1,1,1,1,4,3,1,1,11,1,5,1,6,28,5,1,8,1,21,5,3,2,3,19,9,8,14,3,29,1,1,4,21,7,2,1,3,2,1,24,17,4,1,17,1,5,26,2,27,10,3,3,1,1,6,5,3,27,5,2,12,1,2,1,3,28,1,7,3,8,1,4,5,2,1,1,9,1,1,5,4,6,4,3,7,10,2,4,6,3,15,1,28,2,23,4,5,1,2,19,4,13,3,1,12,3,8,1,15,7,10,8,1,4,2,1,22,4,10,21,8,1,1,1,2,15,3,2,21,17,4,3,3,4,18,9,1,4,1,2,5,1,11,10,8,4,4,27,1,7,2,9,1,2,1,5,20,16,1,3,15,3,1,4,21,21,12,8,2,6,6,20,7,1,8,9,1,1,2,8,1,2,5,2,22,22,9,2,4,6,4,6,2,4,4,3,2,1,1,1,22,1,20,15,6,1,5,1,1,4,12,12,1,3,1,1,1,5,3,3,7,1,4,7,1,16,11,7,5,1,4,9,1,6,11,1,10,1,1,25,15,5,1,2,1,2,1,7,22,7,8,5,10,5,4,9,1,2,1,3,27,4,22,15,2,2,12,2,1,2,7,16,1,11,12,17,3,1,9,1,6,18,1,19,10,1,15,4,4,3,17,9,9,11,9,6,3,1,1,18,2,25,5,1,15,20,1,1,6,1,13,12,1,1,1,1,6,12,1,10,6,25,3,4,1,3,13,2,6,1,3,2,1,6,1,9,2,1,29,8,5,8,1,4,23,1,2,1,6,4,1,16,11,27,6,4,1,17,7,18,1,9,3,9,1,1,3,5,12,12,1,2,9,16,7,2,1,1,1,1,8,8,9,1,1,2,10,5,4,2,1,14,1,4,1,10,1,12,5,16,4,3,5,1,1,16,22,10,4,11,6,3,2,1,8,7,1,1,25,4,6,6,1,1,24,13,2,4,1,17,27,8,3,3,1,22,13,3,1,4,1,1,1,6,1,1,8,1,1,1,9,2,6,1,27,8,1,5,2,1,1,7,14,19,12,17,1,1,8,1,16,1,3,18,3,2,2,18,19,5,6,2,1,1,8,9,14,10,11,4,1,6,3,9,1,1,19,2,28,5,4,14,1,19,1,23,1,3,25,11,1,16,15,17,5,8,18,15,1,1,1,1,2,12,17,7,1,6,2,9,12,4,5,2,20,2,2,5,1,1,1,2,23,9,1,2,1,2,5,17,6,1,3,1,14,1,15,16,2,5,12,7,11,5,1,1,1,1,7,22,13,17,26,5,16,17,3,5,4,18,2,8,19,7,19,8,2,2,4,15,6,5,5,5,3,3,1,1,5,1,2,17,3,1,5,4,1,14,2,19,23,3,27,1,3,1,4,25,2,12,16,1,1,13,5,1,1,19,1,5,2,5,4,7,28,1,4,2,3,23,1,1,6,1,18,3,18,15,1,2,1,10,1,11,1,2,11,6,5,1,15,4,18,3,23,26,2,1,14,5,1,5,9,11,2,1,19,1,1,16,2,6,4,20,1,23,1,5,6,13,5,4,10,21,1,19,1,1,2,6,2,1,1,1,11,6,14,2,11,3,17,10,1,1,1,7,4,2,12,2,5,4,10,6,5,1,1,1,1,9,9,2,2,6,2,12,5,12,2,2,24,8,19,2,4,2,16,14,4,13,1,1,4,1,9,1,13,1,14,1,4,12,6,6,6,2,1,15,1,9,5,4,10,16,24,29,26,15,1,4,7,2,7,1,16,3,2,1,6,1,15,1,4,2,3,1,20,15,7,1,6,4,22,1,2,22,3,4,13,1,1,19,1,7,1,12,20,1,1,14,4,4,11,1,3,1,16,1,10,2,4,6,1,1,1,6,9,4,1,1,6,6,2,9,16,3,2,3,1,5,19,17,18,3,13,1,9,15,3,3,1,14,1,3,1,1,13,18,22,1,1,13,19,1,2,17,10,3,11,2,1,1,5,3,7,1,25,12,22,14,8,4,5,10,12,18,1,26,4,8,12,6,1,1,8,1,1,22,24,7,9,1,1,1,23,3,3,2,21,6,19,1,3,2,6,1,12,17,2,18,8,3,1,11,4,4,1,1,1,1,3,5,2,2,5,3,2,20,9,9,21,1,3,7,9,6,11,5,18,1,12,7,4,4,2,21,10,1,1,1,3,6,1,13,1,4,14,1,11,1,9,4,10,3,8,1,4,1,1,3,19,23,21,2,4,2,5,28,9,7,3,9,7,16,2,1,1,3,25,25,6,16,1,10,1,20,1,1,7,16,13,2,4,2,2,17,1,7,1,2,21,17,1,25,22,10,26,14,2,4,16,7,5,1,10,13,14,11,16,1,1,3,3,1,3,2,8,1,7,24,1,6,3,2,4,5,5,1,9,11,2,9,19,9,5,4,4,1,2,24,17,1,13,11,9,3,24,24,5,20,6,1,23,1,18,3,3,13,2,5,2,1,13,5,4,6,2,8,15,7,1,1,24,7,1,1,12,2,1,6,13,1,11,1,4,4,4,5,12,22,4,7,26,1,6,1,5,1,1,1,3,5,7,16,9,1,5,12,1,9,13,1,1,9,4,3,6,5,1,1,9,3,4,3,1 ...

# %%
plt.figure(figsize=(12,6))
p1=sns.kdeplot(train['Num_words_ST'], shade=True, color="r").set_title('Kernel Distribution of Number Of words')
p1=sns.kdeplot(train['Num_word_text'], shade=True, color="b")

# %%
plt.figure(figsize=(12,6))
p1=sns.kdeplot(train[train['sentiment']=='positive']['difference_in_words'], shade=True, color="b").set_title('Kernel Distribution of Difference in Number Of words')
p2=sns.kdeplot(train[train['sentiment']=='negative']['difference_in_words'], shade=True, color="r")

# %%
train['temp_list'] = train['selected_text'].apply(lambda x:str(x).split())
top = Counter([item for sublist in train['temp_list'] for item in sublist])
temp = pd.DataFrame(top.most_common(20))
temp.columns = ['Common_words','count']
temp.style.background_gradient(cmap='Blues')
# Out:
# <style type="text/css">
# #T_cf315_row0_col1 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_cf315_row1_col1 {
#   background-color: #08468b;
#   color: #f1f1f1;
# }
# #T_cf315_row2_col1 {
#   background-color: #1967ad;
#   color: #f1f1f1;
# }
# #T_cf315_row3_col1 {
#   background-color: #529dcc;
#   color: #f1f1f1;
# }
# #T_cf315_row4_col1 {
#   background-color: #a5cde3;
#   color: #000000;
# }
# #T_cf315_row5_col1 {
#   background-color: #b5d4e9;
#   color: #000000;
# }
# #T_cf315_row6_col1 {
#   background-color: #bfd8ed;
#   color: #000000;
# }
# #T_cf315_row7_col1 {
#   background-color: #c7dbef;
#   color: #000000;
# }
# #T_cf315_row8_col1 {
#   background-color: #cddff1;
#   color: #000000;
# }
# #T_cf315_row9_col1 {
#   background-color: #d0e2f2;
#   color: #000000;
# }
# #T_cf315_row10_col1 {
#   background-color: #d2e3f3;
#   color: #000000;
# }
# #T_cf315_row11_col1 {
#   background-color: #dbe9f6;
#   color: #000000;
# }
# #T_cf315_row12_col1 {
#   background-color: #dce9f6;
#   color: #000000;
# }
# #T_cf315_row13_col1 {
#   background-color: #e8f1fa;
#   color: #000000;
# }
# #T_cf315_row14_col1 {
#   background-color: #eef5fc;
#   color: #000000;
# }
# #T_cf315_row15_col1 {
#   background-color: #f1f7fd;
#   color: #000000;
# }
# #T_cf315_row16_col1 {
#   background-color: #f2f7fd;
#   color: #000000;
# }
# #T_cf315_row17_col1 {
#   background-color: #f5fafe;
#   color: #000000;
# }
# #T_cf315_row18_col1, #T_cf315_row19_col1 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# </style>
# <table id="T_cf315" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_cf315_level0_col0" class="col_heading level0 col0" >Common_words</th>
#       <th id="T_cf315_level0_col1" class="col_heading level0 col1" >count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_cf315_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_cf315_row0_col0" class="data row0 col0" >to</td>
#       <td id="T_cf315_row0_col1" class="data row0 col1" >5190</td>
#     </tr>
#     <tr>
#       <th id="T_cf315_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_cf315_row1_col0" class="data row1 col0" >I</td>
#       <td id="T_cf315_row1_col1" class="data row1 col1" >4842</td>
#     </tr>
#     <tr>
#       <th id="T_cf315_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_cf315_row2_col0" class="data row2 col0" >the</td>
#       <td id="T_cf315_row2_col1" class="data row2 col1" >4303</td>
#     </tr>
#     <tr>
#       <th id="T_cf315_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_cf315_row3_col0" class="data row3 col0" >a</td>
#       <td id="T_cf315_row3_col1" class="data row3 col1" >3427</td>
#     </tr>
#     <tr>
#       <th id="T_cf315_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_cf315_row4_col0" class="data row4 col0" >my</td>
#       <td id="T_cf315_row4_col1" class="data row4 col1" >2503</td>
#     </tr>
#     <tr>
#       <th id="T_cf315_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_cf315_row5_col0" class="data row5 col0" >i</td>
#       <td id="T_cf315_row5_col1" class="data row5 col1" >2298</td>
#     </tr>
#     <tr>
#       <th id="T_cf315_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_cf315_row6_col0" class="data row6 col0" >and</td>
#       <td id="T_cf315_row6_col1" class="data row6 col1" >2164</td>
#     </tr>
#     <tr>
#       <th id="T_cf315_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_cf315_row7_col0" class="data row7 col0" >you</td>
#       <td id="T_cf315_row7_col1" class="data row7 col1" >2072</td>
#     </tr>
#     <tr>
#       <th id="T_cf315_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_cf315_row8_col0" class="data row8 col0" >is</td>
#       <td id="T_cf315_row8_col1" class="data row8 col1" >1944</td>
#     </tr>
#     <tr>
#       <th id="T_cf315_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_cf315_row9_col0" class="data row9 col0" >in</td>
#       <td id="T_cf315_row9_col1" class="data row9 col1" >1864</td>
#     </tr>
#     <tr>
#       <th id="T_cf315_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_cf315_row10_col0" class="data row10 col0" >for</td>
#       <td id="T_cf315_row10_col1" class="data row10 col1" >1821</td>
#     </tr>
#     <tr>
#       <th id="T_cf315_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_cf315_row11_col0" class="data row11 col0" >it</td>
#       <td id="T_cf315_row11_col1" class="data row11 col1" >1636</td>
#     </tr>
#     <tr>
#       <th id="T_cf315_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_cf315_row12_col0" class="data row12 col0" >of</td>
#       <td id="T_cf315_row12_col1" class="data row12 col1" >1611</td>
#     </tr>
#     <tr>
#       <th id="T_cf315_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_cf315_row13_col0" class="data row13 col0" >on</td>
#       <td id="T_cf315_row13_col1" class="data row13 col1" >1358</td>
#     </tr>
#     <tr>
#       <th id="T_cf315_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_cf315_row14_col0" class="data row14 col0" >have</td>
#       <td id="T_cf315_row14_col1" class="data row14 col1" >1226</td>
#     </tr>
#     <tr>
#       <th id="T_cf315_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_cf315_row15_col0" class="data row15 col0" >me</td>
#       <td id="T_cf315_row15_col1" class="data row15 col1" >1187</td>
#     </tr>
#     <tr>
#       <th id="T_cf315_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_cf315_row16_col0" class="data row16 col0" >so</td>
#       <td id="T_cf315_row16_col1" class="data row16 col1" >1165</td>
#     </tr>
#     <tr>
#       <th id="T_cf315_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_cf315_row17_col0" class="data row17 col0" >that</td>
#       <td id="T_cf315_row17_col1" class="data row17 col1" >1077</td>
#     </tr>
#     <tr>
#       <th id="T_cf315_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_cf315_row18_col0" class="data row18 col0" >be</td>
#       <td id="T_cf315_row18_col1" class="data row18 col1" >1047</td>
#     </tr>
#     <tr>
#       <th id="T_cf315_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_cf315_row19_col0" class="data row19 col0" >but</td>
#       <td id="T_cf315_row19_col1" class="data row19 col1" >1043</td>
#     </tr>
#   </tbody>
# </table>

# %%
fig = px.bar(temp, x="count", y="Common_words", title='Commmon Words in Selected Text', orientation='h',
             width=700, height=700,color='Common_words')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="f6d2a056-f084-406e-9867-4d58be27e6c6" class="plotly-graph-div" style="height:700px; width:700px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f6d2a056-f084-406e-9867-4d58be27e6c6")) {                    Plotly.newPlot(                        "f6d2a056-f084-406e-9867-4d58be27e6c6",                        [{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}\u003cbr\u003ecount=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"to","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"to","offsetgroup":"to","orientation":"h","showlegend":true,"textposition":"auto","x":[5190],"xaxis":"x","y":["to"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}\u003cbr\u003ecount=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"I","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"I","offsetgroup":"I","orientation":"h","showlegend":true,"textposition":"auto","x":[4842],"xaxis":"x","y":["I"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}\u003cbr\u003ecount=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"the","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"the","offsetgroup":"the","orientation":"h","showlegend":true,"textposition":"auto","x":[4303],"xaxis":"x","y":["the"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}\u003cbr\u003ecount=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"a","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"a","offsetgroup":"a","orientation":"h","showlegend":true,"textposition":"auto","x":[3427],"xaxis":"x","y":["a"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}\u003cbr\u003ecount=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"my","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"my","offsetgroup":"my","orientation":"h","showlegend":true,"textposition":"auto","x":[2503],"xaxis":"x","y":["my"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}\u003cbr\u003ecount=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"i","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"i","offsetgroup":"i","orientation":"h","showlegend":true,"textposition":"auto","x":[2298],"xaxis":"x","y":["i"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}\u003cbr\u003ecount=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"and","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"and","offsetgroup":"and","orientation":"h","showlegend":true,"textposition":"auto","x":[2164],"xaxis":"x","y":["and"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}\u003cbr\u003ecount=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"you","marker":{"color":"#B6E880","pattern":{"shape":""}},"name":"you","offsetgroup":"you","orientation":"h","showlegend":true,"textposition":"auto","x":[2072],"xaxis":"x","y":["you"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}\u003cbr\u003ecount=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"is","marker":{"color":"#FF97FF","pattern":{"shape":""}},"name":"is","offsetgroup":"is","orientation":"h","showlegend":true,"textposition":"auto","x":[1944],"xaxis":"x","y":["is"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}\u003cbr\u003ecount=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"in","marker":{"color":"#FECB52","pattern":{"shape":""}},"name":"in","offsetgroup":"in","orientation":"h","showlegend":true,"textposition":"auto","x":[1864],"xaxis":"x","y":["in"],"yaxis":"y" ...

# %%
def remove_stopword(x):
    return [y for y in x if y not in stopwords.words('english')]
train['temp_list'] = train['temp_list'].apply(lambda x:remove_stopword(x))

# %%
top = Counter([item for sublist in train['temp_list'] for item in sublist])
temp = pd.DataFrame(top.most_common(20))
temp = temp.iloc[1:,:]
temp.columns = ['Common_words','count']
temp.style.background_gradient(cmap='Purples')
# Out:
# <style type="text/css">
# #T_6d976_row0_col1 {
#   background-color: #3f007d;
#   color: #f1f1f1;
# }
# #T_6d976_row1_col1 {
#   background-color: #5e3a98;
#   color: #f1f1f1;
# }
# #T_6d976_row2_col1 {
#   background-color: #807cba;
#   color: #f1f1f1;
# }
# #T_6d976_row3_col1 {
#   background-color: #8683bd;
#   color: #f1f1f1;
# }
# #T_6d976_row4_col1 {
#   background-color: #8885be;
#   color: #f1f1f1;
# }
# #T_6d976_row5_col1 {
#   background-color: #b3b3d6;
#   color: #000000;
# }
# #T_6d976_row6_col1 {
#   background-color: #bdbedc;
#   color: #000000;
# }
# #T_6d976_row7_col1 {
#   background-color: #e9e8f2;
#   color: #000000;
# }
# #T_6d976_row8_col1, #T_6d976_row9_col1 {
#   background-color: #eae9f3;
#   color: #000000;
# }
# #T_6d976_row10_col1 {
#   background-color: #ebe9f3;
#   color: #000000;
# }
# #T_6d976_row11_col1 {
#   background-color: #eeecf5;
#   color: #000000;
# }
# #T_6d976_row12_col1 {
#   background-color: #efedf5;
#   color: #000000;
# }
# #T_6d976_row13_col1 {
#   background-color: #f1eff6;
#   color: #000000;
# }
# #T_6d976_row14_col1 {
#   background-color: #f3f2f8;
#   color: #000000;
# }
# #T_6d976_row15_col1 {
#   background-color: #f6f4f9;
#   color: #000000;
# }
# #T_6d976_row16_col1 {
#   background-color: #f8f6fa;
#   color: #000000;
# }
# #T_6d976_row17_col1 {
#   background-color: #fbfafc;
#   color: #000000;
# }
# #T_6d976_row18_col1 {
#   background-color: #fcfbfd;
#   color: #000000;
# }
# </style>
# <table id="T_6d976" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6d976_level0_col0" class="col_heading level0 col0" >Common_words</th>
#       <th id="T_6d976_level0_col1" class="col_heading level0 col1" >count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6d976_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_6d976_row0_col0" class="data row0 col0" >I`m</td>
#       <td id="T_6d976_row0_col1" class="data row0 col1" >940</td>
#     </tr>
#     <tr>
#       <th id="T_6d976_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_6d976_row1_col0" class="data row1 col0" >good</td>
#       <td id="T_6d976_row1_col1" class="data row1 col1" >843</td>
#     </tr>
#     <tr>
#       <th id="T_6d976_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_6d976_row2_col0" class="data row2 col0" >get</td>
#       <td id="T_6d976_row2_col1" class="data row2 col1" >741</td>
#     </tr>
#     <tr>
#       <th id="T_6d976_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_6d976_row3_col0" class="data row3 col0" >like</td>
#       <td id="T_6d976_row3_col1" class="data row3 col1" >727</td>
#     </tr>
#     <tr>
#       <th id="T_6d976_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_6d976_row4_col0" class="data row4 col0" >love</td>
#       <td id="T_6d976_row4_col1" class="data row4 col1" >723</td>
#     </tr>
#     <tr>
#       <th id="T_6d976_level0_row5" class="row_heading level0 row5" >6</th>
#       <td id="T_6d976_row5_col0" class="data row5 col0" >day</td>
#       <td id="T_6d976_row5_col1" class="data row5 col1" >627</td>
#     </tr>
#     <tr>
#       <th id="T_6d976_level0_row6" class="row_heading level0 row6" >7</th>
#       <td id="T_6d976_row6_col0" class="data row6 col0" >go</td>
#       <td id="T_6d976_row6_col1" class="data row6 col1" >605</td>
#     </tr>
#     <tr>
#       <th id="T_6d976_level0_row7" class="row_heading level0 row7" >8</th>
#       <td id="T_6d976_row7_col0" class="data row7 col0" >got</td>
#       <td id="T_6d976_row7_col1" class="data row7 col1" >493</td>
#     </tr>
#     <tr>
#       <th id="T_6d976_level0_row8" class="row_heading level0 row8" >9</th>
#       <td id="T_6d976_row8_col0" class="data row8 col0" >don`t</td>
#       <td id="T_6d976_row8_col1" class="data row8 col1" >489</td>
#     </tr>
#     <tr>
#       <th id="T_6d976_level0_row9" class="row_heading level0 row9" >10</th>
#       <td id="T_6d976_row9_col0" class="data row9 col0" >going</td>
#       <td id="T_6d976_row9_col1" class="data row9 col1" >488</td>
#     </tr>
#     <tr>
#       <th id="T_6d976_level0_row10" class="row_heading level0 row10" >11</th>
#       <td id="T_6d976_row10_col0" class="data row10 col0" >-</td>
#       <td id="T_6d976_row10_col1" class="data row10 col1" >486</td>
#     </tr>
#     <tr>
#       <th id="T_6d976_level0_row11" class="row_heading level0 row11" >12</th>
#       <td id="T_6d976_row11_col0" class="data row11 col0" >miss</td>
#       <td id="T_6d976_row11_col1" class="data row11 col1" >476</td>
#     </tr>
#     <tr>
#       <th id="T_6d976_level0_row12" class="row_heading level0 row12" >13</th>
#       <td id="T_6d976_row12_col0" class="data row12 col0" >****</td>
#       <td id="T_6d976_row12_col1" class="data row12 col1" >474</td>
#     </tr>
#     <tr>
#       <th id="T_6d976_level0_row13" class="row_heading level0 row13" >14</th>
#       <td id="T_6d976_row13_col0" class="data row13 col0" >work</td>
#       <td id="T_6d976_row13_col1" class="data row13 col1" >464</td>
#     </tr>
#     <tr>
#       <th id="T_6d976_level0_row14" class="row_heading level0 row14" >15</th>
#       <td id="T_6d976_row14_col0" class="data row14 col0" >really</td>
#       <td id="T_6d976_row14_col1" class="data row14 col1" >451</td>
#     </tr>
#     <tr>
#       <th id="T_6d976_level0_row15" class="row_heading level0 row15" >16</th>
#       <td id="T_6d976_row15_col0" class="data row15 col0" >one</td>
#       <td id="T_6d976_row15_col1" class="data row15 col1" >439</td>
#     </tr>
#     <tr>
#       <th id="T_6d976_level0_row16" class="row_heading level0 row16" >17</th>
#       <td id="T_6d976_row16_col0" class="data row16 col0" >u</td>
#       <td id="T_6d976_row16_col1" class="data row16 col1" >429</td>
#     </tr>
#     <tr>
#       <th id="T_6d976_level0_row17" class="row_heading level0 row17" >18</th>
#       <td id="T_6d976_row17_col0" class="data row17 col0" >it`s</td>
#       <td id="T_6d976_row17_col1" class="data row17 col1" >414</td>
#     </tr>
#     <tr>
#       <th id="T_6d976_level0_row18" class="row_heading level0 row18" >19</th>
#       <td id="T_6d976_row18_col0" class="data row18 col0" >know</td>
#       <td id="T_6d976_row18_col1" class="data row18 col1" >406</td>
#     </tr>
#   </tbody>
# </table>

# %%
fig = px.treemap(temp, path=['Common_words'], values='count',title='Tree of Most Common Words')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="73bd9984-6801-48a5-bdcd-0bc1ea702e5e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("73bd9984-6801-48a5-bdcd-0bc1ea702e5e")) {                    Plotly.newPlot(                        "73bd9984-6801-48a5-bdcd-0bc1ea702e5e",                        [{"branchvalues":"total","domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"labels=%{label}\u003cbr\u003ecount=%{value}\u003cbr\u003eparent=%{parent}\u003cbr\u003eid=%{id}\u003cextra\u003e\u003c\u002fextra\u003e","ids":["****","-","I`m","day","don`t","get","go","going","good","got","it`s","know","like","love","miss","one","really","u","work"],"labels":["****","-","I`m","day","don`t","get","go","going","good","got","it`s","know","like","love","miss","one","really","u","work"],"name":"","parents":["","","","","","","","","","","","","","","","","","",""],"values":[474,486,940,627,489,741,605,488,843,493,414,406,727,723,476,439,451,429,464],"type":"treemap"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewid ...

# %%
train['temp_list1'] = train['text'].apply(lambda x:str(x).split()) #List of words in every row for text
train['temp_list1'] = train['temp_list1'].apply(lambda x:remove_stopword(x)) #Removing Stopwords

# %%
top = Counter([item for sublist in train['temp_list1'] for item in sublist])
temp = pd.DataFrame(top.most_common(25))
temp = temp.iloc[1:,:]
temp.columns = ['Common_words','count']
temp.style.background_gradient(cmap='Blues')
# Out:
# <style type="text/css">
# #T_adc62_row0_col1 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_adc62_row1_col1 {
#   background-color: #3181bd;
#   color: #f1f1f1;
# }
# #T_adc62_row2_col1 {
#   background-color: #519ccc;
#   color: #f1f1f1;
# }
# #T_adc62_row3_col1 {
#   background-color: #6fb0d7;
#   color: #f1f1f1;
# }
# #T_adc62_row4_col1 {
#   background-color: #75b4d8;
#   color: #000000;
# }
# #T_adc62_row5_col1 {
#   background-color: #89bedc;
#   color: #000000;
# }
# #T_adc62_row6_col1 {
#   background-color: #a3cce3;
#   color: #000000;
# }
# #T_adc62_row7_col1 {
#   background-color: #b8d5ea;
#   color: #000000;
# }
# #T_adc62_row8_col1 {
#   background-color: #c7dbef;
#   color: #000000;
# }
# #T_adc62_row9_col1 {
#   background-color: #cddff1;
#   color: #000000;
# }
# #T_adc62_row10_col1 {
#   background-color: #d5e5f4;
#   color: #000000;
# }
# #T_adc62_row11_col1 {
#   background-color: #dceaf6;
#   color: #000000;
# }
# #T_adc62_row12_col1, #T_adc62_row13_col1 {
#   background-color: #e0ecf8;
#   color: #000000;
# }
# #T_adc62_row14_col1 {
#   background-color: #e2edf8;
#   color: #000000;
# }
# #T_adc62_row15_col1 {
#   background-color: #e3eef8;
#   color: #000000;
# }
# #T_adc62_row16_col1 {
#   background-color: #e3eef9;
#   color: #000000;
# }
# #T_adc62_row17_col1 {
#   background-color: #e6f0f9;
#   color: #000000;
# }
# #T_adc62_row18_col1 {
#   background-color: #e9f2fa;
#   color: #000000;
# }
# #T_adc62_row19_col1 {
#   background-color: #eff6fc;
#   color: #000000;
# }
# #T_adc62_row20_col1 {
#   background-color: #f3f8fe;
#   color: #000000;
# }
# #T_adc62_row21_col1 {
#   background-color: #f4f9fe;
#   color: #000000;
# }
# #T_adc62_row22_col1 {
#   background-color: #f6faff;
#   color: #000000;
# }
# #T_adc62_row23_col1 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# </style>
# <table id="T_adc62" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_adc62_level0_col0" class="col_heading level0 col0" >Common_words</th>
#       <th id="T_adc62_level0_col1" class="col_heading level0 col1" >count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_adc62_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_adc62_row0_col0" class="data row0 col0" >I`m</td>
#       <td id="T_adc62_row0_col1" class="data row0 col1" >1696</td>
#     </tr>
#     <tr>
#       <th id="T_adc62_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_adc62_row1_col0" class="data row1 col0" >get</td>
#       <td id="T_adc62_row1_col1" class="data row1 col1" >1373</td>
#     </tr>
#     <tr>
#       <th id="T_adc62_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_adc62_row2_col0" class="data row2 col0" >like</td>
#       <td id="T_adc62_row2_col1" class="data row2 col1" >1258</td>
#     </tr>
#     <tr>
#       <th id="T_adc62_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_adc62_row3_col0" class="data row3 col0" >day</td>
#       <td id="T_adc62_row3_col1" class="data row3 col1" >1165</td>
#     </tr>
#     <tr>
#       <th id="T_adc62_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_adc62_row4_col0" class="data row4 col0" >-</td>
#       <td id="T_adc62_row4_col1" class="data row4 col1" >1147</td>
#     </tr>
#     <tr>
#       <th id="T_adc62_level0_row5" class="row_heading level0 row5" >6</th>
#       <td id="T_adc62_row5_col0" class="data row5 col0" >go</td>
#       <td id="T_adc62_row5_col1" class="data row5 col1" >1101</td>
#     </tr>
#     <tr>
#       <th id="T_adc62_level0_row6" class="row_heading level0 row6" >7</th>
#       <td id="T_adc62_row6_col0" class="data row6 col0" >good</td>
#       <td id="T_adc62_row6_col1" class="data row6 col1" >1032</td>
#     </tr>
#     <tr>
#       <th id="T_adc62_level0_row7" class="row_heading level0 row7" >8</th>
#       <td id="T_adc62_row7_col0" class="data row7 col0" >got</td>
#       <td id="T_adc62_row7_col1" class="data row7 col1" >961</td>
#     </tr>
#     <tr>
#       <th id="T_adc62_level0_row8" class="row_heading level0 row8" >9</th>
#       <td id="T_adc62_row8_col0" class="data row8 col0" >going</td>
#       <td id="T_adc62_row8_col1" class="data row8 col1" >911</td>
#     </tr>
#     <tr>
#       <th id="T_adc62_level0_row9" class="row_heading level0 row9" >10</th>
#       <td id="T_adc62_row9_col0" class="data row9 col0" >love</td>
#       <td id="T_adc62_row9_col1" class="data row9 col1" >880</td>
#     </tr>
#     <tr>
#       <th id="T_adc62_level0_row10" class="row_heading level0 row10" >11</th>
#       <td id="T_adc62_row10_col0" class="data row10 col0" >work</td>
#       <td id="T_adc62_row10_col1" class="data row10 col1" >837</td>
#     </tr>
#     <tr>
#       <th id="T_adc62_level0_row11" class="row_heading level0 row11" >12</th>
#       <td id="T_adc62_row11_col0" class="data row11 col0" >****</td>
#       <td id="T_adc62_row11_col1" class="data row11 col1" >796</td>
#     </tr>
#     <tr>
#       <th id="T_adc62_level0_row12" class="row_heading level0 row12" >13</th>
#       <td id="T_adc62_row12_col0" class="data row12 col0" >one</td>
#       <td id="T_adc62_row12_col1" class="data row12 col1" >775</td>
#     </tr>
#     <tr>
#       <th id="T_adc62_level0_row13" class="row_heading level0 row13" >14</th>
#       <td id="T_adc62_row13_col0" class="data row13 col0" >really</td>
#       <td id="T_adc62_row13_col1" class="data row13 col1" >773</td>
#     </tr>
#     <tr>
#       <th id="T_adc62_level0_row14" class="row_heading level0 row14" >15</th>
#       <td id="T_adc62_row14_col0" class="data row14 col0" >it`s</td>
#       <td id="T_adc62_row14_col1" class="data row14 col1" >767</td>
#     </tr>
#     <tr>
#       <th id="T_adc62_level0_row15" class="row_heading level0 row15" >16</th>
#       <td id="T_adc62_row15_col0" class="data row15 col0" >u</td>
#       <td id="T_adc62_row15_col1" class="data row15 col1" >761</td>
#     </tr>
#     <tr>
#       <th id="T_adc62_level0_row16" class="row_heading level0 row16" >17</th>
#       <td id="T_adc62_row16_col0" class="data row16 col0" >don`t</td>
#       <td id="T_adc62_row16_col1" class="data row16 col1" >759</td>
#     </tr>
#     <tr>
#       <th id="T_adc62_level0_row17" class="row_heading level0 row17" >18</th>
#       <td id="T_adc62_row17_col0" class="data row17 col0" >know</td>
#       <td id="T_adc62_row17_col1" class="data row17 col1" >744</td>
#     </tr>
#     <tr>
#       <th id="T_adc62_level0_row18" class="row_heading level0 row18" >19</th>
#       <td id="T_adc62_row18_col0" class="data row18 col0" >see</td>
#       <td id="T_adc62_row18_col1" class="data row18 col1" >729</td>
#     </tr>
#     <tr>
#       <th id="T_adc62_level0_row19" class="row_heading level0 row19" >20</th>
#       <td id="T_adc62_row19_col0" class="data row19 col0" >back</td>
#       <td id="T_adc62_row19_col1" class="data row19 col1" >697</td>
#     </tr>
#     <tr>
#       <th id="T_adc62_level0_row20" class="row_heading level0 row20" >21</th>
#       <td id="T_adc62_row20_col0" class="data row20 col0" >&</td>
#       <td id="T_adc62_row20_col1" class="data row20 col1" >675</td>
#     </tr>
#     <tr>
#       <th id="T_adc62_level0_row21" class="row_heading level0 row21" >22</th>
#       <td id="T_adc62_row21_col0" class="data row21 col0" >time</td>
#       <td id="T_adc62_row21_col1" class="data row21 col1" >672</td>
#     </tr>
#     <tr>
#       <th id="T_adc62_level0_row22" class="row_heading level0 row22" >23</th>
#       <td id="T_adc62_row22_col0" class="data row22 col0" >want</td>
#       <td id="T_adc62_row22_col1" class="data row22 col1" >660</td>
#     </tr>
#     <tr>
#       <th id="T_adc62_level0_row23" class="row_heading level0 row23" >24</th>
#       <td id="T_adc62_row23_col0" class="data row23 col0" >new</td>
#       <td id="T_adc62_row23_col1" class="data row23 col1" >654</td>
#     </tr>
#   </tbody>
# </table>

# %%
fig = px.bar(temp, x="count", y="Common_words", title='Commmon Words in Text', orientation='h',
             width=700, height=700,color='Common_words')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="8cc6d768-9f13-41a8-aed7-6e47bc397685" class="plotly-graph-div" style="height:700px; width:700px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8cc6d768-9f13-41a8-aed7-6e47bc397685")) {                    Plotly.newPlot(                        "8cc6d768-9f13-41a8-aed7-6e47bc397685",                        [{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}\u003cbr\u003ecount=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"I`m","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"I`m","offsetgroup":"I`m","orientation":"h","showlegend":true,"textposition":"auto","x":[1696],"xaxis":"x","y":["I`m"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}\u003cbr\u003ecount=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"get","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"get","offsetgroup":"get","orientation":"h","showlegend":true,"textposition":"auto","x":[1373],"xaxis":"x","y":["get"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}\u003cbr\u003ecount=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"like","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"like","offsetgroup":"like","orientation":"h","showlegend":true,"textposition":"auto","x":[1258],"xaxis":"x","y":["like"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}\u003cbr\u003ecount=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"day","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"day","offsetgroup":"day","orientation":"h","showlegend":true,"textposition":"auto","x":[1165],"xaxis":"x","y":["day"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}\u003cbr\u003ecount=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"-","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"-","offsetgroup":"-","orientation":"h","showlegend":true,"textposition":"auto","x":[1147],"xaxis":"x","y":["-"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}\u003cbr\u003ecount=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"go","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"go","offsetgroup":"go","orientation":"h","showlegend":true,"textposition":"auto","x":[1101],"xaxis":"x","y":["go"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}\u003cbr\u003ecount=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"good","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"good","offsetgroup":"good","orientation":"h","showlegend":true,"textposition":"auto","x":[1032],"xaxis":"x","y":["good"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}\u003cbr\u003ecount=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"got","marker":{"color":"#B6E880","pattern":{"shape":""}},"name":"got","offsetgroup":"got","orientation":"h","showlegend":true,"textposition":"auto","x":[961],"xaxis":"x","y":["got"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}\u003cbr\u003ecount=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"going","marker":{"color":"#FF97FF","pattern":{"shape":""}},"name":"going","offsetgroup":"going","orientation":"h","showlegend":true,"textposition":"auto","x":[911],"xaxis":"x","y":["going"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}\u003cbr\u003ecount=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"love","marker":{"color":"#FECB52","pattern":{"shape":""}},"name":"love","offsetgroup":"love","orientation":"h","showlegend":true,"textposition":"auto"," ...

# %%
Positive_sent = train[train['sentiment']=='positive']
Negative_sent = train[train['sentiment']=='negative']
Neutral_sent = train[train['sentiment']=='neutral']

# %%
#MosT common positive words
top = Counter([item for sublist in Positive_sent['temp_list'] for item in sublist])
temp_positive = pd.DataFrame(top.most_common(20))
temp_positive.columns = ['Common_words','count']
temp_positive.style.background_gradient(cmap='Greens')
# Out:
# <style type="text/css">
# #T_cda18_row0_col1 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_cda18_row1_col1 {
#   background-color: #1a843f;
#   color: #f1f1f1;
# }
# #T_cda18_row2_col1 {
#   background-color: #238b45;
#   color: #f1f1f1;
# }
# #T_cda18_row3_col1 {
#   background-color: #84cc83;
#   color: #000000;
# }
# #T_cda18_row4_col1 {
#   background-color: #c1e6ba;
#   color: #000000;
# }
# #T_cda18_row5_col1 {
#   background-color: #c4e8bd;
#   color: #000000;
# }
# #T_cda18_row6_col1 {
#   background-color: #daf0d4;
#   color: #000000;
# }
# #T_cda18_row7_col1 {
#   background-color: #def2d9;
#   color: #000000;
# }
# #T_cda18_row8_col1 {
#   background-color: #e0f3db;
#   color: #000000;
# }
# #T_cda18_row9_col1 {
#   background-color: #e3f4de;
#   color: #000000;
# }
# #T_cda18_row10_col1, #T_cda18_row11_col1 {
#   background-color: #e9f7e5;
#   color: #000000;
# }
# #T_cda18_row12_col1 {
#   background-color: #ebf7e7;
#   color: #000000;
# }
# #T_cda18_row13_col1 {
#   background-color: #ecf8e8;
#   color: #000000;
# }
# #T_cda18_row14_col1 {
#   background-color: #f2faf0;
#   color: #000000;
# }
# #T_cda18_row15_col1, #T_cda18_row16_col1, #T_cda18_row17_col1 {
#   background-color: #f5fbf3;
#   color: #000000;
# }
# #T_cda18_row18_col1, #T_cda18_row19_col1 {
#   background-color: #f7fcf5;
#   color: #000000;
# }
# </style>
# <table id="T_cda18" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_cda18_level0_col0" class="col_heading level0 col0" >Common_words</th>
#       <th id="T_cda18_level0_col1" class="col_heading level0 col1" >count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_cda18_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_cda18_row0_col0" class="data row0 col0" >I</td>
#       <td id="T_cda18_row0_col1" class="data row0 col1" >684</td>
#     </tr>
#     <tr>
#       <th id="T_cda18_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_cda18_row1_col0" class="data row1 col0" >love</td>
#       <td id="T_cda18_row1_col1" class="data row1 col1" >556</td>
#     </tr>
#     <tr>
#       <th id="T_cda18_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_cda18_row2_col0" class="data row2 col0" >good</td>
#       <td id="T_cda18_row2_col1" class="data row2 col1" >539</td>
#     </tr>
#     <tr>
#       <th id="T_cda18_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_cda18_row3_col0" class="data row3 col0" >Happy</td>
#       <td id="T_cda18_row3_col1" class="data row3 col1" >371</td>
#     </tr>
#     <tr>
#       <th id="T_cda18_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_cda18_row4_col0" class="data row4 col0" >happy</td>
#       <td id="T_cda18_row4_col1" class="data row4 col1" >264</td>
#     </tr>
#     <tr>
#       <th id="T_cda18_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_cda18_row5_col0" class="data row5 col0" >great</td>
#       <td id="T_cda18_row5_col1" class="data row5 col1" >258</td>
#     </tr>
#     <tr>
#       <th id="T_cda18_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_cda18_row6_col0" class="data row6 col0" >day</td>
#       <td id="T_cda18_row6_col1" class="data row6 col1" >208</td>
#     </tr>
#     <tr>
#       <th id="T_cda18_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_cda18_row7_col0" class="data row7 col0" >fun</td>
#       <td id="T_cda18_row7_col1" class="data row7 col1" >197</td>
#     </tr>
#     <tr>
#       <th id="T_cda18_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_cda18_row8_col0" class="data row8 col0" >nice</td>
#       <td id="T_cda18_row8_col1" class="data row8 col1" >192</td>
#     </tr>
#     <tr>
#       <th id="T_cda18_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_cda18_row9_col0" class="data row9 col0" >thanks</td>
#       <td id="T_cda18_row9_col1" class="data row9 col1" >185</td>
#     </tr>
#     <tr>
#       <th id="T_cda18_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_cda18_row10_col0" class="data row10 col0" >hope</td>
#       <td id="T_cda18_row10_col1" class="data row10 col1" >165</td>
#     </tr>
#     <tr>
#       <th id="T_cda18_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_cda18_row11_col0" class="data row11 col0" >Good</td>
#       <td id="T_cda18_row11_col1" class="data row11 col1" >165</td>
#     </tr>
#     <tr>
#       <th id="T_cda18_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_cda18_row12_col0" class="data row12 col0" >like</td>
#       <td id="T_cda18_row12_col1" class="data row12 col1" >158</td>
#     </tr>
#     <tr>
#       <th id="T_cda18_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_cda18_row13_col0" class="data row13 col0" >Thanks</td>
#       <td id="T_cda18_row13_col1" class="data row13 col1" >153</td>
#     </tr>
#     <tr>
#       <th id="T_cda18_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_cda18_row14_col0" class="data row14 col0" >wish</td>
#       <td id="T_cda18_row14_col1" class="data row14 col1" >128</td>
#     </tr>
#     <tr>
#       <th id="T_cda18_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_cda18_row15_col0" class="data row15 col0" >awesome</td>
#       <td id="T_cda18_row15_col1" class="data row15 col1" >115</td>
#     </tr>
#     <tr>
#       <th id="T_cda18_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_cda18_row16_col0" class="data row16 col0" >best</td>
#       <td id="T_cda18_row16_col1" class="data row16 col1" >115</td>
#     </tr>
#     <tr>
#       <th id="T_cda18_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_cda18_row17_col0" class="data row17 col0" >really</td>
#       <td id="T_cda18_row17_col1" class="data row17 col1" >115</td>
#     </tr>
#     <tr>
#       <th id="T_cda18_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_cda18_row18_col0" class="data row18 col0" >I`m</td>
#       <td id="T_cda18_row18_col1" class="data row18 col1" >109</td>
#     </tr>
#     <tr>
#       <th id="T_cda18_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_cda18_row19_col0" class="data row19 col0" >better</td>
#       <td id="T_cda18_row19_col1" class="data row19 col1" >108</td>
#     </tr>
#   </tbody>
# </table>

# %%
fig = px.bar(temp_positive, x="count", y="Common_words", title='Most Commmon Positive Words', orientation='h',
             width=700, height=700,color='Common_words')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="4fc9b63a-feec-4823-af1d-659da879eded" class="plotly-graph-div" style="height:700px; width:700px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4fc9b63a-feec-4823-af1d-659da879eded")) {                    Plotly.newPlot(                        "4fc9b63a-feec-4823-af1d-659da879eded",                        [{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}\u003cbr\u003ecount=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"I","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"I","offsetgroup":"I","orientation":"h","showlegend":true,"textposition":"auto","x":[684],"xaxis":"x","y":["I"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}\u003cbr\u003ecount=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"love","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"love","offsetgroup":"love","orientation":"h","showlegend":true,"textposition":"auto","x":[556],"xaxis":"x","y":["love"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}\u003cbr\u003ecount=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"good","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"good","offsetgroup":"good","orientation":"h","showlegend":true,"textposition":"auto","x":[539],"xaxis":"x","y":["good"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}\u003cbr\u003ecount=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Happy","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Happy","offsetgroup":"Happy","orientation":"h","showlegend":true,"textposition":"auto","x":[371],"xaxis":"x","y":["Happy"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}\u003cbr\u003ecount=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"happy","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"happy","offsetgroup":"happy","orientation":"h","showlegend":true,"textposition":"auto","x":[264],"xaxis":"x","y":["happy"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}\u003cbr\u003ecount=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"great","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"great","offsetgroup":"great","orientation":"h","showlegend":true,"textposition":"auto","x":[258],"xaxis":"x","y":["great"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}\u003cbr\u003ecount=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"day","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"day","offsetgroup":"day","orientation":"h","showlegend":true,"textposition":"auto","x":[208],"xaxis":"x","y":["day"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}\u003cbr\u003ecount=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"fun","marker":{"color":"#B6E880","pattern":{"shape":""}},"name":"fun","offsetgroup":"fun","orientation":"h","showlegend":true,"textposition":"auto","x":[197],"xaxis":"x","y":["fun"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}\u003cbr\u003ecount=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"nice","marker":{"color":"#FF97FF","pattern":{"shape":""}},"name":"nice","offsetgroup":"nice","orientation":"h","showlegend":true,"textposition":"auto","x":[192],"xaxis":"x","y":["nice"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}\u003cbr\u003ecount=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"thanks","marker":{"color":"#FECB52","pattern":{"shape":""}},"name":"thanks","offsetgroup":"thanks","orientation":"h","showlegend":true, ...

# %%
#MosT common negative words
top = Counter([item for sublist in Negative_sent['temp_list'] for item in sublist])
temp_negative = pd.DataFrame(top.most_common(20))
temp_negative = temp_negative.iloc[1:,:]
temp_negative.columns = ['Common_words','count']
temp_negative.style.background_gradient(cmap='Reds')
# Out:
# <style type="text/css">
# #T_6d23d_row0_col1 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_6d23d_row1_col1 {
#   background-color: #ed392b;
#   color: #f1f1f1;
# }
# #T_6d23d_row2_col1 {
#   background-color: #f34a36;
#   color: #f1f1f1;
# }
# #T_6d23d_row3_col1 {
#   background-color: #f6553c;
#   color: #f1f1f1;
# }
# #T_6d23d_row4_col1 {
#   background-color: #fb7858;
#   color: #f1f1f1;
# }
# #T_6d23d_row5_col1 {
#   background-color: #fc8161;
#   color: #f1f1f1;
# }
# #T_6d23d_row6_col1 {
#   background-color: #fc8f6f;
#   color: #000000;
# }
# #T_6d23d_row7_col1 {
#   background-color: #fcb095;
#   color: #000000;
# }
# #T_6d23d_row8_col1 {
#   background-color: #fcb499;
#   color: #000000;
# }
# #T_6d23d_row9_col1 {
#   background-color: #fcb89e;
#   color: #000000;
# }
# #T_6d23d_row10_col1 {
#   background-color: #fdd7c6;
#   color: #000000;
# }
# #T_6d23d_row11_col1 {
#   background-color: #fed9c9;
#   color: #000000;
# }
# #T_6d23d_row12_col1 {
#   background-color: #fee2d5;
#   color: #000000;
# }
# #T_6d23d_row13_col1 {
#   background-color: #fee8de;
#   color: #000000;
# }
# #T_6d23d_row14_col1 {
#   background-color: #ffeee7;
#   color: #000000;
# }
# #T_6d23d_row15_col1 {
#   background-color: #ffefe8;
#   color: #000000;
# }
# #T_6d23d_row16_col1 {
#   background-color: #fff1ea;
#   color: #000000;
# }
# #T_6d23d_row17_col1 {
#   background-color: #fff3ed;
#   color: #000000;
# }
# #T_6d23d_row18_col1 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# </style>
# <table id="T_6d23d" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6d23d_level0_col0" class="col_heading level0 col0" >Common_words</th>
#       <th id="T_6d23d_level0_col1" class="col_heading level0 col1" >count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6d23d_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_6d23d_row0_col0" class="data row0 col0" >miss</td>
#       <td id="T_6d23d_row0_col1" class="data row0 col1" >337</td>
#     </tr>
#     <tr>
#       <th id="T_6d23d_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_6d23d_row1_col0" class="data row1 col0" >I`m</td>
#       <td id="T_6d23d_row1_col1" class="data row1 col1" >243</td>
#     </tr>
#     <tr>
#       <th id="T_6d23d_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_6d23d_row2_col0" class="data row2 col0" >****</td>
#       <td id="T_6d23d_row2_col1" class="data row2 col1" >231</td>
#     </tr>
#     <tr>
#       <th id="T_6d23d_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_6d23d_row3_col0" class="data row3 col0" >sad</td>
#       <td id="T_6d23d_row3_col1" class="data row3 col1" >224</td>
#     </tr>
#     <tr>
#       <th id="T_6d23d_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_6d23d_row4_col0" class="data row4 col0" >hate</td>
#       <td id="T_6d23d_row4_col1" class="data row4 col1" >199</td>
#     </tr>
#     <tr>
#       <th id="T_6d23d_level0_row5" class="row_heading level0 row5" >6</th>
#       <td id="T_6d23d_row5_col0" class="data row5 col0" >bad</td>
#       <td id="T_6d23d_row5_col1" class="data row5 col1" >192</td>
#     </tr>
#     <tr>
#       <th id="T_6d23d_level0_row6" class="row_heading level0 row6" >7</th>
#       <td id="T_6d23d_row6_col0" class="data row6 col0" >sorry</td>
#       <td id="T_6d23d_row6_col1" class="data row6 col1" >181</td>
#     </tr>
#     <tr>
#       <th id="T_6d23d_level0_row7" class="row_heading level0 row7" >8</th>
#       <td id="T_6d23d_row7_col0" class="data row7 col0" >like</td>
#       <td id="T_6d23d_row7_col1" class="data row7 col1" >155</td>
#     </tr>
#     <tr>
#       <th id="T_6d23d_level0_row8" class="row_heading level0 row8" >9</th>
#       <td id="T_6d23d_row8_col0" class="data row8 col0" >don`t</td>
#       <td id="T_6d23d_row8_col1" class="data row8 col1" >152</td>
#     </tr>
#     <tr>
#       <th id="T_6d23d_level0_row9" class="row_heading level0 row9" >10</th>
#       <td id="T_6d23d_row9_col0" class="data row9 col0" >feel</td>
#       <td id="T_6d23d_row9_col1" class="data row9 col1" >149</td>
#     </tr>
#     <tr>
#       <th id="T_6d23d_level0_row10" class="row_heading level0 row10" >11</th>
#       <td id="T_6d23d_row10_col0" class="data row10 col0" >really</td>
#       <td id="T_6d23d_row10_col1" class="data row10 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_6d23d_level0_row11" class="row_heading level0 row11" >12</th>
#       <td id="T_6d23d_row11_col0" class="data row11 col0" >can`t</td>
#       <td id="T_6d23d_row11_col1" class="data row11 col1" >121</td>
#     </tr>
#     <tr>
#       <th id="T_6d23d_level0_row12" class="row_heading level0 row12" >13</th>
#       <td id="T_6d23d_row12_col0" class="data row12 col0" >sick</td>
#       <td id="T_6d23d_row12_col1" class="data row12 col1" >112</td>
#     </tr>
#     <tr>
#       <th id="T_6d23d_level0_row13" class="row_heading level0 row13" >14</th>
#       <td id="T_6d23d_row13_col0" class="data row13 col0" >good</td>
#       <td id="T_6d23d_row13_col1" class="data row13 col1" >102</td>
#     </tr>
#     <tr>
#       <th id="T_6d23d_level0_row14" class="row_heading level0 row14" >15</th>
#       <td id="T_6d23d_row14_col0" class="data row14 col0" >im</td>
#       <td id="T_6d23d_row14_col1" class="data row14 col1" >93</td>
#     </tr>
#     <tr>
#       <th id="T_6d23d_level0_row15" class="row_heading level0 row15" >16</th>
#       <td id="T_6d23d_row15_col0" class="data row15 col0" >get</td>
#       <td id="T_6d23d_row15_col1" class="data row15 col1" >92</td>
#     </tr>
#     <tr>
#       <th id="T_6d23d_level0_row16" class="row_heading level0 row16" >17</th>
#       <td id="T_6d23d_row16_col0" class="data row16 col0" >tired</td>
#       <td id="T_6d23d_row16_col1" class="data row16 col1" >89</td>
#     </tr>
#     <tr>
#       <th id="T_6d23d_level0_row17" class="row_heading level0 row17" >18</th>
#       <td id="T_6d23d_row17_col0" class="data row17 col0" >sucks</td>
#       <td id="T_6d23d_row17_col1" class="data row17 col1" >86</td>
#     </tr>
#     <tr>
#       <th id="T_6d23d_level0_row18" class="row_heading level0 row18" >19</th>
#       <td id="T_6d23d_row18_col0" class="data row18 col0" >day</td>
#       <td id="T_6d23d_row18_col1" class="data row18 col1" >83</td>
#     </tr>
#   </tbody>
# </table>

# %%
fig = px.bar(temp_negative, x="count", y="Common_words", title='Most Commmon Negative Words', orientation='h',
             width=700, height=700,color='Common_words')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="c7fe6c74-34c1-4c94-b0c7-f8d5aa6e15ac" class="plotly-graph-div" style="height:700px; width:700px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c7fe6c74-34c1-4c94-b0c7-f8d5aa6e15ac")) {                    Plotly.newPlot(                        "c7fe6c74-34c1-4c94-b0c7-f8d5aa6e15ac",                        [{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}\u003cbr\u003ecount=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"miss","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"miss","offsetgroup":"miss","orientation":"h","showlegend":true,"textposition":"auto","x":[337],"xaxis":"x","y":["miss"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}\u003cbr\u003ecount=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"I`m","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"I`m","offsetgroup":"I`m","orientation":"h","showlegend":true,"textposition":"auto","x":[243],"xaxis":"x","y":["I`m"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}\u003cbr\u003ecount=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"****","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"****","offsetgroup":"****","orientation":"h","showlegend":true,"textposition":"auto","x":[231],"xaxis":"x","y":["****"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}\u003cbr\u003ecount=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"sad","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"sad","offsetgroup":"sad","orientation":"h","showlegend":true,"textposition":"auto","x":[224],"xaxis":"x","y":["sad"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}\u003cbr\u003ecount=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"hate","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"hate","offsetgroup":"hate","orientation":"h","showlegend":true,"textposition":"auto","x":[199],"xaxis":"x","y":["hate"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}\u003cbr\u003ecount=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"bad","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"bad","offsetgroup":"bad","orientation":"h","showlegend":true,"textposition":"auto","x":[192],"xaxis":"x","y":["bad"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}\u003cbr\u003ecount=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"sorry","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"sorry","offsetgroup":"sorry","orientation":"h","showlegend":true,"textposition":"auto","x":[181],"xaxis":"x","y":["sorry"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}\u003cbr\u003ecount=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"like","marker":{"color":"#B6E880","pattern":{"shape":""}},"name":"like","offsetgroup":"like","orientation":"h","showlegend":true,"textposition":"auto","x":[155],"xaxis":"x","y":["like"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}\u003cbr\u003ecount=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"don`t","marker":{"color":"#FF97FF","pattern":{"shape":""}},"name":"don`t","offsetgroup":"don`t","orientation":"h","showlegend":true,"textposition":"auto","x":[152],"xaxis":"x","y":["don`t"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}\u003cbr\u003ecount=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"feel","marker":{"color":"#FECB52","pattern":{"shape":""}},"name":"feel","offsetgroup":"feel","orientation":"h","showlegend":true,"t ...

# %%
#MosT common Neutral words
top = Counter([item for sublist in Neutral_sent['temp_list'] for item in sublist])
temp_neutral = pd.DataFrame(top.most_common(20))
temp_neutral = temp_neutral.loc[1:,:]
temp_neutral.columns = ['Common_words','count']
temp_neutral.style.background_gradient(cmap='Reds')
# Out:
# <style type="text/css">
# #T_a654d_row0_col1, #T_a654d_row1_col1 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_a654d_row2_col1 {
#   background-color: #db2824;
#   color: #f1f1f1;
# }
# #T_a654d_row3_col1 {
#   background-color: #fc7f5f;
#   color: #f1f1f1;
# }
# #T_a654d_row4_col1 {
#   background-color: #fc8a6a;
#   color: #f1f1f1;
# }
# #T_a654d_row5_col1 {
#   background-color: #fc9b7c;
#   color: #000000;
# }
# #T_a654d_row6_col1 {
#   background-color: #fca588;
#   color: #000000;
# }
# #T_a654d_row7_col1 {
#   background-color: #fcbea5;
#   color: #000000;
# }
# #T_a654d_row8_col1 {
#   background-color: #fdccb8;
#   color: #000000;
# }
# #T_a654d_row9_col1 {
#   background-color: #fdcebb;
#   color: #000000;
# }
# #T_a654d_row10_col1, #T_a654d_row11_col1 {
#   background-color: #fedfd0;
#   color: #000000;
# }
# #T_a654d_row12_col1 {
#   background-color: #fee1d4;
#   color: #000000;
# }
# #T_a654d_row13_col1 {
#   background-color: #fee5d8;
#   color: #000000;
# }
# #T_a654d_row14_col1 {
#   background-color: #fee7dc;
#   color: #000000;
# }
# #T_a654d_row15_col1, #T_a654d_row16_col1 {
#   background-color: #feeae1;
#   color: #000000;
# }
# #T_a654d_row17_col1 {
#   background-color: #ffece3;
#   color: #000000;
# }
# #T_a654d_row18_col1 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# </style>
# <table id="T_a654d" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a654d_level0_col0" class="col_heading level0 col0" >Common_words</th>
#       <th id="T_a654d_level0_col1" class="col_heading level0 col1" >count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a654d_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_a654d_row0_col0" class="data row0 col0" >I`m</td>
#       <td id="T_a654d_row0_col1" class="data row0 col1" >588</td>
#     </tr>
#     <tr>
#       <th id="T_a654d_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_a654d_row1_col0" class="data row1 col0" >get</td>
#       <td id="T_a654d_row1_col1" class="data row1 col1" >587</td>
#     </tr>
#     <tr>
#       <th id="T_a654d_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_a654d_row2_col0" class="data row2 col0" >go</td>
#       <td id="T_a654d_row2_col1" class="data row2 col1" >493</td>
#     </tr>
#     <tr>
#       <th id="T_a654d_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_a654d_row3_col0" class="data row3 col0" >like</td>
#       <td id="T_a654d_row3_col1" class="data row3 col1" >414</td>
#     </tr>
#     <tr>
#       <th id="T_a654d_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_a654d_row4_col0" class="data row4 col0" >-</td>
#       <td id="T_a654d_row4_col1" class="data row4 col1" >403</td>
#     </tr>
#     <tr>
#       <th id="T_a654d_level0_row5" class="row_heading level0 row5" >6</th>
#       <td id="T_a654d_row5_col0" class="data row5 col0" >got</td>
#       <td id="T_a654d_row5_col1" class="data row5 col1" >387</td>
#     </tr>
#     <tr>
#       <th id="T_a654d_level0_row6" class="row_heading level0 row6" >7</th>
#       <td id="T_a654d_row6_col0" class="data row6 col0" >going</td>
#       <td id="T_a654d_row6_col1" class="data row6 col1" >377</td>
#     </tr>
#     <tr>
#       <th id="T_a654d_level0_row7" class="row_heading level0 row7" >8</th>
#       <td id="T_a654d_row7_col0" class="data row7 col0" >work</td>
#       <td id="T_a654d_row7_col1" class="data row7 col1" >353</td>
#     </tr>
#     <tr>
#       <th id="T_a654d_level0_row8" class="row_heading level0 row8" >9</th>
#       <td id="T_a654d_row8_col0" class="data row8 col0" >know</td>
#       <td id="T_a654d_row8_col1" class="data row8 col1" >339</td>
#     </tr>
#     <tr>
#       <th id="T_a654d_level0_row9" class="row_heading level0 row9" >10</th>
#       <td id="T_a654d_row9_col0" class="data row9 col0" >day</td>
#       <td id="T_a654d_row9_col1" class="data row9 col1" >336</td>
#     </tr>
#     <tr>
#       <th id="T_a654d_level0_row10" class="row_heading level0 row10" >11</th>
#       <td id="T_a654d_row10_col0" class="data row10 col0" >u</td>
#       <td id="T_a654d_row10_col1" class="data row10 col1" >320</td>
#     </tr>
#     <tr>
#       <th id="T_a654d_level0_row11" class="row_heading level0 row11" >12</th>
#       <td id="T_a654d_row11_col0" class="data row11 col0" >one</td>
#       <td id="T_a654d_row11_col1" class="data row11 col1" >320</td>
#     </tr>
#     <tr>
#       <th id="T_a654d_level0_row12" class="row_heading level0 row12" >13</th>
#       <td id="T_a654d_row12_col0" class="data row12 col0" >see</td>
#       <td id="T_a654d_row12_col1" class="data row12 col1" >316</td>
#     </tr>
#     <tr>
#       <th id="T_a654d_level0_row13" class="row_heading level0 row13" >14</th>
#       <td id="T_a654d_row13_col0" class="data row13 col0" >back</td>
#       <td id="T_a654d_row13_col1" class="data row13 col1" >310</td>
#     </tr>
#     <tr>
#       <th id="T_a654d_level0_row14" class="row_heading level0 row14" >15</th>
#       <td id="T_a654d_row14_col0" class="data row14 col0" >don`t</td>
#       <td id="T_a654d_row14_col1" class="data row14 col1" >305</td>
#     </tr>
#     <tr>
#       <th id="T_a654d_level0_row15" class="row_heading level0 row15" >16</th>
#       <td id="T_a654d_row15_col0" class="data row15 col0" >it`s</td>
#       <td id="T_a654d_row15_col1" class="data row15 col1" >299</td>
#     </tr>
#     <tr>
#       <th id="T_a654d_level0_row16" class="row_heading level0 row16" >17</th>
#       <td id="T_a654d_row16_col0" class="data row16 col0" >want</td>
#       <td id="T_a654d_row16_col1" class="data row16 col1" >299</td>
#     </tr>
#     <tr>
#       <th id="T_a654d_level0_row17" class="row_heading level0 row17" >18</th>
#       <td id="T_a654d_row17_col0" class="data row17 col0" >time</td>
#       <td id="T_a654d_row17_col1" class="data row17 col1" >297</td>
#     </tr>
#     <tr>
#       <th id="T_a654d_level0_row18" class="row_heading level0 row18" >19</th>
#       <td id="T_a654d_row18_col0" class="data row18 col0" >new</td>
#       <td id="T_a654d_row18_col1" class="data row18 col1" >279</td>
#     </tr>
#   </tbody>
# </table>

# %%
fig = px.bar(temp_neutral, x="count", y="Common_words", title='Most Commmon Neutral Words', orientation='h',
             width=700, height=700,color='Common_words')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="22750e71-0808-4913-8f1b-1e6fa4bb9d44" class="plotly-graph-div" style="height:700px; width:700px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("22750e71-0808-4913-8f1b-1e6fa4bb9d44")) {                    Plotly.newPlot(                        "22750e71-0808-4913-8f1b-1e6fa4bb9d44",                        [{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}\u003cbr\u003ecount=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"I`m","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"I`m","offsetgroup":"I`m","orientation":"h","showlegend":true,"textposition":"auto","x":[588],"xaxis":"x","y":["I`m"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}\u003cbr\u003ecount=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"get","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"get","offsetgroup":"get","orientation":"h","showlegend":true,"textposition":"auto","x":[587],"xaxis":"x","y":["get"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}\u003cbr\u003ecount=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"go","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"go","offsetgroup":"go","orientation":"h","showlegend":true,"textposition":"auto","x":[493],"xaxis":"x","y":["go"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}\u003cbr\u003ecount=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"like","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"like","offsetgroup":"like","orientation":"h","showlegend":true,"textposition":"auto","x":[414],"xaxis":"x","y":["like"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}\u003cbr\u003ecount=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"-","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"-","offsetgroup":"-","orientation":"h","showlegend":true,"textposition":"auto","x":[403],"xaxis":"x","y":["-"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}\u003cbr\u003ecount=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"got","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"got","offsetgroup":"got","orientation":"h","showlegend":true,"textposition":"auto","x":[387],"xaxis":"x","y":["got"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}\u003cbr\u003ecount=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"going","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"going","offsetgroup":"going","orientation":"h","showlegend":true,"textposition":"auto","x":[377],"xaxis":"x","y":["going"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}\u003cbr\u003ecount=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"work","marker":{"color":"#B6E880","pattern":{"shape":""}},"name":"work","offsetgroup":"work","orientation":"h","showlegend":true,"textposition":"auto","x":[353],"xaxis":"x","y":["work"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}\u003cbr\u003ecount=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"know","marker":{"color":"#FF97FF","pattern":{"shape":""}},"name":"know","offsetgroup":"know","orientation":"h","showlegend":true,"textposition":"auto","x":[339],"xaxis":"x","y":["know"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}\u003cbr\u003ecount=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"day","marker":{"color":"#FECB52","pattern":{"shape":""}},"name":"day","offsetgroup":"day","orientation":"h","showlegend":true,"textposition":"auto","x":[33 ...

# %%
fig = px.treemap(temp_neutral, path=['Common_words'], values='count',title='Tree Of Most Common Neutral Words')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="c3fe6e0a-4ce8-4670-aaff-bcddd39d4c26" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c3fe6e0a-4ce8-4670-aaff-bcddd39d4c26")) {                    Plotly.newPlot(                        "c3fe6e0a-4ce8-4670-aaff-bcddd39d4c26",                        [{"branchvalues":"total","domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"labels=%{label}\u003cbr\u003ecount=%{value}\u003cbr\u003eparent=%{parent}\u003cbr\u003eid=%{id}\u003cextra\u003e\u003c\u002fextra\u003e","ids":["-","I`m","back","day","don`t","get","go","going","got","it`s","know","like","new","one","see","time","u","want","work"],"labels":["-","I`m","back","day","don`t","get","go","going","got","it`s","know","like","new","one","see","time","u","want","work"],"name":"","parents":["","","","","","","","","","","","","","","","","","",""],"values":[403,588,310,336,305,587,493,377,387,299,339,414,279,320,316,297,320,299,353],"type":"treemap"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"t ...

# %%
raw_text = [word for word_list in train['temp_list1'] for word in word_list]

# %%
def words_unique(sentiment,numwords,raw_words):
    '''
    Input:
        segment - Segment category (ex. 'Neutral');
        numwords - how many specific words do you want to see in the final result;
        raw_words - list  for item in train_data[train_data.segments == segments]['temp_list1']:
    Output:
        dataframe giving information about the name of the specific ingredient and how many times it occurs in the chosen cuisine (in descending order based on their counts)..

    '''
    allother = []
    for item in train[train.sentiment != sentiment]['temp_list1']:
        for word in item:
            allother .append(word)
    allother  = list(set(allother ))

    specificnonly = [x for x in raw_text if x not in allother]

    mycounter = Counter()

    for item in train[train.sentiment == sentiment]['temp_list1']:
        for word in item:
            mycounter[word] += 1
    keep = list(specificnonly)

    for word in list(mycounter):
        if word not in keep:
            del mycounter[word]

    Unique_words = pd.DataFrame(mycounter.most_common(numwords), columns = ['words','count'])

    return Unique_words

# %%
Unique_Positive= words_unique('positive', 20, raw_text)
print("The top 20 unique words in Positive Tweets are:")
Unique_Positive.style.background_gradient(cmap='Greens')
# Out:
# The top 20 unique words in Positive Tweets are:
# <style type="text/css">
# #T_caf66_row0_col1 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_caf66_row1_col1 {
#   background-color: #37a055;
#   color: #f1f1f1;
# }
# #T_caf66_row2_col1 {
#   background-color: #73c476;
#   color: #000000;
# }
# #T_caf66_row3_col1 {
#   background-color: #92d28f;
#   color: #000000;
# }
# #T_caf66_row4_col1 {
#   background-color: #aedea7;
#   color: #000000;
# }
# #T_caf66_row5_col1, #T_caf66_row6_col1 {
#   background-color: #c7e9c0;
#   color: #000000;
# }
# #T_caf66_row7_col1, #T_caf66_row8_col1, #T_caf66_row9_col1, #T_caf66_row10_col1, #T_caf66_row11_col1 {
#   background-color: #dbf1d6;
#   color: #000000;
# }
# #T_caf66_row12_col1, #T_caf66_row13_col1, #T_caf66_row14_col1, #T_caf66_row15_col1, #T_caf66_row16_col1, #T_caf66_row17_col1, #T_caf66_row18_col1 {
#   background-color: #ebf7e7;
#   color: #000000;
# }
# #T_caf66_row19_col1 {
#   background-color: #f7fcf5;
#   color: #000000;
# }
# </style>
# <table id="T_caf66" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_caf66_level0_col0" class="col_heading level0 col0" >words</th>
#       <th id="T_caf66_level0_col1" class="col_heading level0 col1" >count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_caf66_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_caf66_row0_col0" class="data row0 col0" >Thanks,</td>
#       <td id="T_caf66_row0_col1" class="data row0 col1" >18</td>
#     </tr>
#     <tr>
#       <th id="T_caf66_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_caf66_row1_col0" class="data row1 col0" >amazing.</td>
#       <td id="T_caf66_row1_col1" class="data row1 col1" >14</td>
#     </tr>
#     <tr>
#       <th id="T_caf66_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_caf66_row2_col0" class="data row2 col0" >Lovely</td>
#       <td id="T_caf66_row2_col1" class="data row2 col1" >12</td>
#     </tr>
#     <tr>
#       <th id="T_caf66_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_caf66_row3_col0" class="data row3 col0" >Moms</td>
#       <td id="T_caf66_row3_col1" class="data row3 col1" >11</td>
#     </tr>
#     <tr>
#       <th id="T_caf66_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_caf66_row4_col0" class="data row4 col0" >Watched</td>
#       <td id="T_caf66_row4_col1" class="data row4 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_caf66_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_caf66_row5_col0" class="data row5 col0" >thnx</td>
#       <td id="T_caf66_row5_col1" class="data row5 col1" >9</td>
#     </tr>
#     <tr>
#       <th id="T_caf66_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_caf66_row6_col0" class="data row6 col0" >hilarious</td>
#       <td id="T_caf66_row6_col1" class="data row6 col1" >9</td>
#     </tr>
#     <tr>
#       <th id="T_caf66_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_caf66_row7_col0" class="data row7 col0" >Goodmorning</td>
#       <td id="T_caf66_row7_col1" class="data row7 col1" >8</td>
#     </tr>
#     <tr>
#       <th id="T_caf66_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_caf66_row8_col0" class="data row8 col0" >successful</td>
#       <td id="T_caf66_row8_col1" class="data row8 col1" >8</td>
#     </tr>
#     <tr>
#       <th id="T_caf66_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_caf66_row9_col0" class="data row9 col0" >sweet,</td>
#       <td id="T_caf66_row9_col1" class="data row9 col1" >8</td>
#     </tr>
#     <tr>
#       <th id="T_caf66_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_caf66_row10_col0" class="data row10 col0" >welcome.</td>
#       <td id="T_caf66_row10_col1" class="data row10 col1" >8</td>
#     </tr>
#     <tr>
#       <th id="T_caf66_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_caf66_row11_col0" class="data row11 col0" >gr8</td>
#       <td id="T_caf66_row11_col1" class="data row11 col1" >8</td>
#     </tr>
#     <tr>
#       <th id="T_caf66_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_caf66_row12_col0" class="data row12 col0" >Loves</td>
#       <td id="T_caf66_row12_col1" class="data row12 col1" >7</td>
#     </tr>
#     <tr>
#       <th id="T_caf66_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_caf66_row13_col0" class="data row13 col0" >adorable</td>
#       <td id="T_caf66_row13_col1" class="data row13 col1" >7</td>
#     </tr>
#     <tr>
#       <th id="T_caf66_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_caf66_row14_col0" class="data row14 col0" >STAR</td>
#       <td id="T_caf66_row14_col1" class="data row14 col1" >7</td>
#     </tr>
#     <tr>
#       <th id="T_caf66_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_caf66_row15_col0" class="data row15 col0" >Day!!</td>
#       <td id="T_caf66_row15_col1" class="data row15 col1" >7</td>
#     </tr>
#     <tr>
#       <th id="T_caf66_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_caf66_row16_col0" class="data row16 col0" >Awesome!</td>
#       <td id="T_caf66_row16_col1" class="data row16 col1" >7</td>
#     </tr>
#     <tr>
#       <th id="T_caf66_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_caf66_row17_col0" class="data row17 col0" >Congratulations</td>
#       <td id="T_caf66_row17_col1" class="data row17 col1" >7</td>
#     </tr>
#     <tr>
#       <th id="T_caf66_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_caf66_row18_col0" class="data row18 col0" >ay</td>
#       <td id="T_caf66_row18_col1" class="data row18 col1" >7</td>
#     </tr>
#     <tr>
#       <th id="T_caf66_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_caf66_row19_col0" class="data row19 col0" >congratulations</td>
#       <td id="T_caf66_row19_col1" class="data row19 col1" >6</td>
#     </tr>
#   </tbody>
# </table>

# %%
Unique_Neutral= words_unique('neutral', 10, raw_text)
print("The top 10 unique words in Neutral Tweets are:")
Unique_Neutral.style.background_gradient(cmap='Oranges')
# Out:
# The top 10 unique words in Neutral Tweets are:
# <style type="text/css">
# #T_74561_row0_col1 {
#   background-color: #7f2704;
#   color: #f1f1f1;
# }
# #T_74561_row1_col1 {
#   background-color: #f3701b;
#   color: #f1f1f1;
# }
# #T_74561_row2_col1 {
#   background-color: #fda762;
#   color: #000000;
# }
# #T_74561_row3_col1, #T_74561_row4_col1 {
#   background-color: #fdd9b4;
#   color: #000000;
# }
# #T_74561_row5_col1, #T_74561_row6_col1, #T_74561_row7_col1, #T_74561_row8_col1, #T_74561_row9_col1 {
#   background-color: #fff5eb;
#   color: #000000;
# }
# </style>
# <table id="T_74561" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_74561_level0_col0" class="col_heading level0 col0" >words</th>
#       <th id="T_74561_level0_col1" class="col_heading level0 col1" >count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_74561_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_74561_row0_col0" class="data row0 col0" >hows</td>
#       <td id="T_74561_row0_col1" class="data row0 col1" >11</td>
#     </tr>
#     <tr>
#       <th id="T_74561_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_74561_row1_col0" class="data row1 col0" >??????</td>
#       <td id="T_74561_row1_col1" class="data row1 col1" >9</td>
#     </tr>
#     <tr>
#       <th id="T_74561_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_74561_row2_col0" class="data row2 col0" >???????</td>
#       <td id="T_74561_row2_col1" class="data row2 col1" >8</td>
#     </tr>
#     <tr>
#       <th id="T_74561_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_74561_row3_col0" class="data row3 col0" >settings</td>
#       <td id="T_74561_row3_col1" class="data row3 col1" >7</td>
#     </tr>
#     <tr>
#       <th id="T_74561_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_74561_row4_col0" class="data row4 col0" >time?</td>
#       <td id="T_74561_row4_col1" class="data row4 col1" >7</td>
#     </tr>
#     <tr>
#       <th id="T_74561_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_74561_row5_col0" class="data row5 col0" >Nighty</td>
#       <td id="T_74561_row5_col1" class="data row5 col1" >6</td>
#     </tr>
#     <tr>
#       <th id="T_74561_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_74561_row6_col0" class="data row6 col0" >mite</td>
#       <td id="T_74561_row6_col1" class="data row6 col1" >6</td>
#     </tr>
#     <tr>
#       <th id="T_74561_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_74561_row7_col0" class="data row7 col0" >Sat</td>
#       <td id="T_74561_row7_col1" class="data row7 col1" >6</td>
#     </tr>
#     <tr>
#       <th id="T_74561_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_74561_row8_col0" class="data row8 col0" >try.</td>
#       <td id="T_74561_row8_col1" class="data row8 col1" >6</td>
#     </tr>
#     <tr>
#       <th id="T_74561_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_74561_row9_col0" class="data row9 col0" >school...</td>
#       <td id="T_74561_row9_col1" class="data row9 col1" >6</td>
#     </tr>
#   </tbody>
# </table>

# %%
# !pip install emoji
# Out:
# Collecting emoji
#   Downloading emoji-2.10.1-py2.py3-none-any.whl (421 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 421.5/421.5 kB 6.1 MB/s eta 0:00:00
# Installing collected packages: emoji
# Successfully installed emoji-2.10.1

# %%
from wordcloud import WordCloud, STOPWORDS
negative_df = train[train['sentiment'] == 'negative']
positive_df = train[train['sentiment'] == 'positive']
neutral_df = train[train['sentiment'] == 'neutral']

# Define a function to generate and display a WordCloud
def generate_wordcloud(data, title):
    words = ' '.join(data['text'])
    cleaned_word = " ".join([word for word in words.split()
                            if 'http' not in word
                                and not word.startswith('@')
                                and word != 'RT' ])
    wordcloud = WordCloud(stopwords=STOPWORDS,background_color='white',
                          width=3000, height=800).generate(cleaned_word)
    plt.figure(figsize=(15, 5))
    plt.imshow(wordcloud, interpolation='bilinear')
    plt.title(title)
    plt.axis('off')
    plt.show()
# Generate and display WordClouds for each sentiment category
generate_wordcloud(negative_df, 'Negative Sentiment WordCloud')
generate_wordcloud(positive_df, 'Positive Sentiment WordCloud')
generate_wordcloud(neutral_df, 'Neutral Sentiment WordCloud')
